# %%
from numpy import random

x = random.randint(100)

print(x)
# Out:
# 77

# %%
from numpy import random

x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(100))

print(x)
# Out:
# [5 7 5 7 5 7 5 7 7 7 5 7 7 7 3 5 7 7 7 5 5 3 7 7 7 7 7 7 7 3 7 7 5 5 5 7 7
#  7 7 3 5 7 7 7 7 3 7 7 7 5 7 3 5 5 7 3 7 7 5 5 7 7 5 7 7 7 7 5 7 3 7 5 7 7
#  7 7 7 3 5 3 5 5 3 7 7 5 7 5 7 7 7 7 5 5 7 5 5 5 7 7]

# %%
from numpy import random

x = random.normal(size=(2, 3))

print(x)
# Out:
# [[-1.01672343  1.0886516   0.15711804]
#  [-0.89856575  0.00594491  1.49756758]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.normal(size=1000), hist=False)

plt.show()

# %%
from numpy import random

x = random.binomial(n=10, p=0.5, size=10)

print(x)
# Out:
# [5 5 4 7 4 6 3 8 3 9]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)

plt.show()

# %%
from numpy import random

x = random.poisson(lam=2, size=10)

print(x)
# Out:
# [0 4 2 3 2 0 2 4 3 0]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.poisson(lam=2, size=1000), kde=False)

plt.show()

# %%
from numpy import random

x = random.uniform(size=(2, 3))

print(x)
# Out:
# [[0.15466345 0.841672   0.54132616]
#  [0.10497169 0.27132328 0.66075241]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.uniform(size=1000), hist=False)

plt.show()

# %%
from numpy import random

x = random.chisquare(df=2, size=(2, 3))

print(x)
# Out:
# [[0.15081721 1.73400834 0.09042725]
#  [0.78041521 0.33060913 0.87741095]]

# %%
from numpy import random

x = random.logistic(loc=1, scale=2, size=(2, 3))

print(x)
# Out:
# [[ 1.34742059  1.6133732  -1.59780143]
#  [ 5.55724721  3.76984491  1.21409472]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.logistic(size=1000), hist=False)

plt.show()

# %%
from numpy import random

x = random.multinomial(n=6, pvals=[1/6, 1/6, 1/6, 1/6, 1/6, 1/6])

print(x)
# Out:
# [1 2 2 1 0 0]

# %%
from numpy import random

x = random.exponential(scale=2, size=(2, 3))

print(x)
# Out:
# [[2.70051243 1.07978448 0.02608046]
#  [1.19213024 3.04073998 0.6053887 ]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.exponential(size=1000), hist=False)

plt.show()
